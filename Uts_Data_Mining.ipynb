# %% [markdown]
# <a href="https://colab.research.google.com/github/Zydenn37/Yajit/blob/main/Uts_Data_Mining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Bagian 1: Preprocessing
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Upload file CSV
from google.colab import files
uploaded = files.upload()

# Baca data
df = pd.read_csv(next(iter(uploaded)))
print("Data Awal:")
display(df.head())
# Out:
#      <input type="file" id="files-cbd28ac1-46af-4a2d-94a0-672b271d9c7c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cbd28ac1-46af-4a2d-94a0-672b271d9c7c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='pendapatan', y='pembelian_tahunan', hue='loyalitas')
plt.title('Pendapatan vs Pembelian Tahunan')
plt.xlabel('Pendapatan')
plt.ylabel('Pembelian Tahunan')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Membaca data dari file CSV
df = pd.read_csv("data_pelanggan.csv")  # Ganti dengan path file Anda jika perlu

# 2. Menampilkan 5 baris pertama sebagai pratinjau
print("Pratinjau Data:")
print(df.head())

# 3. Menampilkan ringkasan statistik
print("\nRingkasan Statistik:")
print(df.describe())

# 4. Mengecek nilai kosong
print("\nJumlah Data Kosong:")
print(df.isnull().sum())

# 5. Visualisasi hubungan antara pendapatan dan pembelian tahunan
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='pendapatan', y='pembelian_tahunan', hue='loyalitas')
plt.title('Hubungan antara Pendapatan dan Pembelian Tahunan')
plt.xlabel('Pendapatan')
plt.ylabel('Pembelian Tahunan')
plt.legend(title='Loyalitas')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Pratinjau Data:
#    umur  pendapatan  pembelian_tahunan    loyalitas
# 0    58          77                  6  Tidak Loyal
# 1    48          52                  8  Tidak Loyal
# 2    34          91                  5  Tidak Loyal
# 3    27         117                  4  Tidak Loyal
# 4    40          66                  2  Tidak Loyal
#
# Ringkasan Statistik:
#              umur  pendapatan  pembelian_tahunan
# count  100.000000  100.000000         100.000000
# mean    38.790000   74.090000           6.660000
# std     11.556008   26.947797           3.929222
# min     20.000000   30.000000           1.000000
# 25%     28.000000   55.250000           3.000000
# 50%     39.500000   75.000000           6.000000
# 75%     47.250000   92.500000           9.000000
# max     59.000000  119.000000          14.000000
#
# Jumlah Data Kosong:
# umur                 0
# pendapatan           0
# pembelian_tahunan    0
# loyalitas            0
# dtype: int64

# %%
# 8. K-Nearest Neighbors Classifier
knn_model = KNeighborsClassifier(n_neighbors=5)
knn_model.fit(X_train, y_train)
knn_preds = knn_model.predict(X_test)

# 9. Evaluasi Model
print("\nDecision Tree Accuracy:", accuracy_score(y_test, dt_preds))
print("KNN Accuracy:", accuracy_score(y_test, knn_preds))

print("\nDecision Tree Classification Report:")
print(classification_report(y_test, dt_preds, target_names=le.classes_))

print("Confusion Matrix (Decision Tree):")
print(confusion_matrix(y_test, dt_preds))

print("\nKNN Classification Report:")
print(classification_report(y_test, knn_preds, target_names=le.classes_))

print("Confusion Matrix (KNN):")
print(confusion_matrix(y_test, knn_preds))
# Out:
#   File "<ipython-input-14-3683acd6c9af>", line 20
#     print(confusion_matrix(y_test, knn_preds))
#                                   ^
# SyntaxError: invalid non-printable character U+00A0

# %%
# Bagian 3: Analisis Perbandingan

dt_accuracy = accuracy_score(y_test, dt_preds)
knn_accuracy = accuracy_score(y_test, knn_preds)

print("\nAnalisis Perbandingan")
print(f"Akurasi Decision Tree: {dt_accuracy:.2f}")
print(f"Akurasi KNN: {knn_accuracy:.2f}")

if dt_accuracy > knn_accuracy:
    print("Model yang lebih akurat: Decision Tree")
elif knn_accuracy > dt_accuracy:
    print("Model yang lebih akurat: KNN")
else:
    print("Keduanya memiliki akurasi yang sama.")

# Konsistensi klasifikasi
import numpy as np
consistency = np.mean(dt_preds == knn_preds)
print(f"Tingkat konsistensi hasil klasifikasi: {consistency:.2f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-4f127b3f4bd8> in <cell line: 0>()
#       1 # Bagian 3: Analisis Perbandingan
#       2
# ----> 3 dt_accuracy = accuracy_score(y_test, dt_preds)
#       4 knn_accuracy = accuracy_score(y_test, knn_preds)
#       5
#
# NameError: name 'accuracy_score' is not defined
